# %% [markdown]
# # Instructions
# This notebook downloads table data from [King Arthur](https://www.kingarthurbaking.com/learn/ingredient-weight-chart). The data is processed in a similar way to USDA notebook and the USDA endpoint is also queried to find the fdcId for each ingredient. The data is then saved to a json file.

# %% [markdown]
# ### Parameters

# %%
# URL of the HTML page
url = "https://www.kingarthurbaking.com/learn/ingredient-weight-chart"

# %%
import pandas as pd
import requests
import time
import os

# %% [markdown]
# ### Download King Arthur Data

# %%
# Send a GET request to the URL and get the HTML content
response = requests.get(url)
html_content = response.text

# Read the HTML table into a pandas DataFrame
dfs = pd.read_html(html_content)

# Extract the table you want (assuming it's the first table on the page)
df = dfs[0]
df['fdcId'] = pd.Series()
df = df.drop(columns=["Ounces"])
df = df.rename(columns={"Ingredient": "description", "Grams": "gramWeight"})
df = df[['fdcId', 'description', 'gramWeight', 'Volume']]
# Out:
# C:\Users\jluca\AppData\Local\Temp\ipykernel_22852\921725010.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(html_content)

# %% [markdown]
# ### Cleanup data

# %%
def get_value_from_volume(volume: str) -> float:
    volume_parts = volume.split(' ')
    return pd.eval('+'.join(volume_parts[0:len(volume_parts)-2]) if len(volume_parts) > 2 else volume_parts[0])

def get_uom_from_volume(volume: str) -> float:
    volume_parts = volume.split(' ')
    return volume_parts[-1] if volume_parts[-1] != 'large' else "each"

df['Volume'] = df['Volume'].str.replace(r" {0,1}\(.*\)|\u00AD|\u00AD","", regex=True)
df['description'] = df['description'].str.replace(r" {0,1}\(.*\)|\u00AD|\u00AD","", regex=True)
df['foodPortions'] = df.apply(lambda x: [{'gramWeight': x['gramWeight'].split(' to ')[0], 'value': get_value_from_volume(x["Volume"]), 'uom': get_uom_from_volume(x["Volume"])}], axis=1)

df = df.drop(columns=["gramWeight", "Volume"])
df = df.drop_duplicates(subset='description', keep="last")

df.head(100)
# Out:
#     fdcId               description  \
# 0     NaN          '00' Pizza Flour
# 1     NaN               Agave syrup
# 2     NaN         All-Purpose Flour
# 3     NaN              Almond Flour
# 4     NaN               Almond meal
# ..    ...                       ...
# 117   NaN               Durum Flour
# 118   NaN  Easy Roll Dough Improver
# 119   NaN                       Egg
# 120   NaN                 Egg white
# 121   NaN                Egg whites
#
#                                           foodPortions
# 0    [{'gramWeight': '116', 'value': 1, 'uom': 'cup'}]
# 1    [{'gramWeight': '84', 'value': 0.25, 'uom': 'c...
# 2    [{'gramWeight': '120', 'value': 1, 'uom': 'cup'}]
# 3     [{'gramWeight': '96', 'value': 1, 'uom': 'cup'}]
# 4     [{'gramWeight': '84', 'value': 1, 'uom': 'cup'}]
# ..                                                 ...
# 117  [{'gramWeight': '124', 'value': 1, 'uom': 'cup'}]
# 118  [{'gramWeight': '18', 'value': 2, 'uom': 'tabl...
# 119  [{'gramWeight': '50', 'value': 1, 'uom': 'each'}]
# 120  [{'gramWeight': '35', 'value': 1, 'uom': 'each'}]
# 121  [{'gramWeight': '11', 'value': 2, 'uom': 'tabl...
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Cleanup "bad" data

# %%
items_to_remove = ["Barley", "Coconut", "Corn", "Cranberries", "Flaxseed", "Quinoa", "Raisins", "Water", "Almonds"]
df = df[~df["description"].isin(items_to_remove)]
df['search_description'] = df['description']
items_to_replace = {"Almonds": "Almond Nuts", 
                    "Brown rice": "Brown rice raw",
                    "Buckwheat": "Buckwheat grain",
                    "Egg": "Whole egg",
                    "Egg yolk": "Egg yolk large",
                    "Milk": "Whole milk vitamin",
                    "Oats": "Rolled oats",
                    "Olives": "Green olives",
                    "Peanuts": "Peanuts raw",
                    "Rice": "White rice grain",
                    "Salt": "Table salt",
                    "Butter": "Butter stick"
                    }
df['search_description'] = df['search_description'].replace(items_to_replace)

df.head(10)
# Out:
#    fdcId              description  \
# 0    NaN         '00' Pizza Flour
# 1    NaN              Agave syrup
# 2    NaN        All-Purpose Flour
# 3    NaN             Almond Flour
# 4    NaN              Almond meal
# 5    NaN             Almond paste
# 8    NaN           Almonds, whole
# 9    NaN           Amaranth flour
# 10   NaN  Apple juice concentrate
# 12   NaN                   Apples
#
#                                          foodPortions       search_description
# 0   [{'gramWeight': '116', 'value': 1, 'uom': 'cup'}]         '00' Pizza Flour
# 1   [{'gramWeight': '84', 'value': 0.25, 'uom': 'c...              Agave syrup
# 2   [{'gramWeight': '120', 'value': 1, 'uom': 'cup'}]        All-Purpose Flour
# 3    [{'gramWeight': '96', 'value': 1, 'uom': 'cup'}]             Almond Flour
# 4    [{'gramWeight': '84', 'value': 1, 'uom': 'cup'}]              Almond meal
# 5   [{'gramWeight': '259', 'value': 1, 'uom': 'cup'}]             Almond paste
# 8   [{'gramWeight': '142', 'value': 1, 'uom': 'cup'}]           Almonds, whole
# 9   [{'gramWeight': '103', 'value': 1, 'uom': 'cup'}]           Amaranth flour
# 10  [{'gramWeight': '70', 'value': 0.25, 'uom': 'c...  Apple juice concentrate
# 12  [{'gramWeight': '113', 'value': 1, 'uom': 'cup'}]                   Apples

# %% [markdown]
# ### Get data from USDA

# %%
usda_api_key = os.environ['USDA_KEY']
df['fdcDescription'] = pd.Series()

for index, row in df.iterrows():
    description = row['search_description']
    
    url = f"https://api.nal.usda.gov/fdc/v1/foods/search?query={description}&pageSize=1&requireAllWords=true&dataType=Foundation&api_key={usda_api_key}"
    response = requests.get(url)
    data = response.json()

    if 'foods' in data and len(data['foods']) > 0:
        df.at[index, 'fdcId'] = data['foods'][0]['fdcId']
        df.at[index, 'fdcDescription'] = data['foods'][0]['description']
    
    time.sleep(.5)

df.head(20)
# Out:
#       fdcId               description  \
# 0       NaN          '00' Pizza Flour
# 1       NaN               Agave syrup
# 2    789890         All-Purpose Flour
# 3   2261420              Almond Flour
# 4       NaN               Almond meal
# 5       NaN              Almond paste
# 8   2346393            Almonds, whole
# 9   2512371            Amaranth flour
# 10  2003590   Apple juice concentrate
# 12  1750340                    Apples
# 13  2346414                Applesauce
# 14      NaN                  Apricots
# 15      NaN       Artisan Bread Flour
# 16      NaN     Artisan Bread Topping
# 17      NaN  Baker's Cinnamon Filling
# 18      NaN       Baker's Fruit Blend
# 19      NaN     Baker's Special Sugar
# 20      NaN             Baking powder
# 21      NaN               Baking soda
# 22      NaN  Baking Sugar Alternative
#
#                                          foodPortions  \
# 0   [{'gramWeight': '116', 'value': 1, 'uom': 'cup'}]
# 1   [{'gramWeight': '84', 'value': 0.25, 'uom': 'c...
# 2   [{'gramWeight': '120', 'value': 1, 'uom': 'cup'}]
# 3    [{'gramWeight': '96', 'value': 1, 'uom': 'cup'}]
# 4    [{'gramWeight': '84', 'value': 1, 'uom': 'cup'}]
# 5   [{'gramWeight': '259', 'value': 1, 'uom': 'cup'}]
# 8   [{'gramWeight': '142', 'value': 1, 'uom': 'cup'}]
# 9   [{'gramWeight': '103', 'value': 1, 'uom': 'cup'}]
# 10  [{'gramWeight': '70', 'value': 0.25, 'uom': 'c...
# 12  [{'gramWeight': '113', 'value': 1, 'uom': 'cup'}]
# 13  [{'gramWeight': '255', 'value': 1, 'uom': 'cup'}]
# 14  [{'gramWeight': '64', 'value': 0.5, 'uom': 'cu...
# 15  [{'gramWeight': '120', 'value': 1, 'uom': 'cup'}]
# 16  [{'gramWeight': '43', 'value': 0.25, 'uom': 'c...
# 17  [{'gramWeight': '152', 'value': 1, 'uom': 'cup'}]
# 18  [{'gramWeight': '128', 'value': 1, 'uom': 'cup'}]
# 19  [{'gramWeight': '190', 'value': 1, 'uom': 'cup'}]
# 20  [{'gramWeight': '4', 'value': 1, 'uom': 'teasp...
# 21  [{'gramWeight': '3', 'value': 0.5, 'uom': 'tea...
# 22  [{'gramWeight': '170', 'value': 1, 'uom': 'cup'}]
#
#           search_description  \
# 0           '00' Pizza Flour
# 1                Agave syrup
# 2          All-Purpose Flour
# 3               Almond Flour
# 4                Almond meal
# 5               Almond paste
# 8             Almonds, whole
# 9             Amaranth flour
# 10   Apple juice concentrate
# 12                    Apples
# 13                Applesauce
# 14                  Apricots
# 15       Artisan Bread Flour
# 16     Artisan Bread Topping
# 17  Baker's Cinnamon Filling
# 18       Baker's Fruit Blend
# 19     Baker's Special Sugar
# 20             Baking powder
# 21               Baking soda
# 22  Baking Sugar Alternative
#
#                                        fdcDescription
# 0                                                 NaN
# 1                                                 NaN
# 2       Flour, wheat, all-purpose, enriched, bleached
# 3                                       Flour, almond
# 4                                                 NaN
# 5                                                 NaN
# 8                           Nuts, almonds, whole, raw
# 9                                     Flour, amaranth
# 10  Apple juice, with added vitamin C, from concen...
# 12                       Apples, fuji, with skin, raw
# 13      Applesauce, unsweetened, with added vitamin C
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN

# %% [markdown]
# ### Filter out items not found in USDA data

# %%
df_filtered = df[df['fdcId'].notnull()]
df_filtered.head(10)
# Out:
#       fdcId              description  \
# 2    789890        All-Purpose Flour
# 3   2261420             Almond Flour
# 8   2346393           Almonds, whole
# 9   2512371           Amaranth flour
# 10  2003590  Apple juice concentrate
# 12  1750340                   Apples
# 13  2346414               Applesauce
# 23  1105073                  Bananas
# 27  2512376             Barley flour
# 30  2258588             Bell peppers
#
#                                          foodPortions  \
# 2   [{'gramWeight': '120', 'value': 1, 'uom': 'cup'}]
# 3    [{'gramWeight': '96', 'value': 1, 'uom': 'cup'}]
# 8   [{'gramWeight': '142', 'value': 1, 'uom': 'cup'}]
# 9   [{'gramWeight': '103', 'value': 1, 'uom': 'cup'}]
# 10  [{'gramWeight': '70', 'value': 0.25, 'uom': 'c...
# 12  [{'gramWeight': '113', 'value': 1, 'uom': 'cup'}]
# 13  [{'gramWeight': '255', 'value': 1, 'uom': 'cup'}]
# 23  [{'gramWeight': '227', 'value': 1, 'uom': 'cup'}]
# 27   [{'gramWeight': '85', 'value': 1, 'uom': 'cup'}]
# 30  [{'gramWeight': '142', 'value': 1, 'uom': 'cup'}]
#
#          search_description                                     fdcDescription
# 2         All-Purpose Flour      Flour, wheat, all-purpose, enriched, bleached
# 3              Almond Flour                                      Flour, almond
# 8            Almonds, whole                          Nuts, almonds, whole, raw
# 9            Amaranth flour                                    Flour, amaranth
# 10  Apple juice concentrate  Apple juice, with added vitamin C, from concen...
# 12                   Apples                       Apples, fuji, with skin, raw
# 13               Applesauce      Applesauce, unsweetened, with added vitamin C
# 23                  Bananas                             Bananas, overripe, raw
# 27             Barley flour                                      Flour, barley
# 30             Bell peppers                          Peppers, bell, green, raw

# %% [markdown]
# ### Export to CSV for manual review

# %%
df_filtered.to_json('king_arthur_data.json', orient='records')
