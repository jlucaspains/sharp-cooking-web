# %% [markdown]
# # Instructions
# This notebook downloads json data from [USDA FoodData Central](https://fdc.nal.usda.gov/download-datasets.html). The data pulled is the "Foundation Foods" and only the food portions are downloaded. The data is then processed and saved to CosmosDB.

# %% [markdown]
# ### Parameters

# %%
# URL of the zip file to download
zip_url = "https://fdc.nal.usda.gov/fdc-datasets/FoodData_Central_foundation_food_json_2023-10-26.zip"
json_file = "foundationDownload.json"
# Path to save the downloaded zip file
zip_file_path = "data.zip"
# Path to extract the contents of the zip file
extract_path = "extracted_data"

# %%
import pandas as pd
import requests
import zipfile
import json

# %% [markdown]
# ### Download and unzip USDA foundation foods json file

# %%
# Download the zip file
response = requests.get(zip_url)
with open(zip_file_path, "wb") as file:
    file.write(response.content)

# Extract the contents of the zip file
with zipfile.ZipFile(zip_file_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

# Path to the extracted JSON file
json_file_path = f"{extract_path}/{json_file}"

# Read the JSON file
with open(json_file_path, "r") as file:
    data = json.load(file)


df = pd.DataFrame(data["FoundationFoods"])
df = df[["fdcId","description", "foodPortions", "foodNutrients"]]
df.head(10)
# Out:
#     fdcId                                        description  \
# 0  321358                                 Hummus, commercial
# 1  321360                               Tomatoes, grape, raw
# 2  321611  Beans, snap, green, canned, regular pack, drai...
# 3  323121                        Frankfurter, beef, unheated
# 4  323294        Nuts, almonds, dry roasted, with salt added
# 5  323505                                          Kale, raw
# 6  323604               Egg, whole, raw, frozen, pasteurized
# 7  323697               Egg, white, raw, frozen, pasteurized
# 8  323793                                  Egg, white, dried
# 9  324317  Onion rings, breaded, par fried, frozen, prepa...
#
#                                         foodPortions  \
# 0  [{'id': 118804, 'value': 2.0, 'measureUnit': {...
# 1  [{'id': 118808, 'value': 5.0, 'measureUnit': {...
# 2  [{'id': 118859, 'value': 1.0, 'measureUnit': {...
# 3  [{'id': 118987, 'value': 1.0, 'measureUnit': {...
# 4  [{'id': 119012, 'value': 1.0, 'measureUnit': {...
# 5  [{'id': 119057, 'value': 1.0, 'measureUnit': {...
# 6  [{'id': 119060, 'value': 1.0, 'measureUnit': {...
# 7  [{'id': 119063, 'value': 1.0, 'measureUnit': {...
# 8  [{'id': 119069, 'value': 1.0, 'measureUnit': {...
# 9  [{'id': 119129, 'value': 1.0, 'measureUnit': {...
#
#                                        foodNutrients
# 0  [{'type': 'FoodNutrient', 'id': 2219707, 'nutr...
# 1  [{'type': 'FoodNutrient', 'id': 2219983, 'nutr...
# 2  [{'type': 'FoodNutrient', 'id': 2220526, 'nutr...
# 3  [{'type': 'FoodNutrient', 'id': 2227684, 'nutr...
# 4  [{'type': 'FoodNutrient', 'id': 2228441, 'nutr...
# 5  [{'type': 'FoodNutrient', 'id': 2229543, 'nutr...
# 6  [{'type': 'FoodNutrient', 'id': 2229844, 'nutr...
# 7  [{'type': 'FoodNutrient', 'id': 2230115, 'nutr...
# 8  [{'type': 'FoodNutrient', 'id': 2230379, 'nutr...
# 9  [{'type': 'FoodNutrient', 'id': 2232163, 'nutr...

# %% [markdown]
# ### Extract food portions for each food item in json file

# %%
nutrients = [
    "298", "606", "646", "645", "601", "307", "205", 
    "291", "203", "328", "301", "303", "306", "208", 
    "269.3"
]
df["foodPortions"] = df["foodPortions"].apply(lambda x: [{'gramWeight': y["gramWeight"], 'value': y["value"], 'modifier': y["modifier"] if "modifier" in y else '', 'uom': y["measureUnit"]["abbreviation"]} for y in x])
df["foodNutrients"] = df["foodNutrients"].apply(lambda x: [{'number': y["nutrient"]["number"], 'name': y["nutrient"]["name"], 'uom': y["nutrient"]["unitName"], 'amount': y["amount"] if "amount" in y else 0} for y in x])
df["foodNutrients"] = df["foodNutrients"].apply(lambda x: [y for y in x if y["amount"] > 0 and (y["number"] in nutrients)])

df.head(10)
# Out:
#     fdcId                                        description  \
# 0  321358                                 Hummus, commercial
# 1  321360                               Tomatoes, grape, raw
# 2  321611  Beans, snap, green, canned, regular pack, drai...
# 3  323121                        Frankfurter, beef, unheated
# 4  323294        Nuts, almonds, dry roasted, with salt added
# 5  323505                                          Kale, raw
# 6  323604               Egg, whole, raw, frozen, pasteurized
# 7  323697               Egg, white, raw, frozen, pasteurized
# 8  323793                                  Egg, white, dried
# 9  324317  Onion rings, breaded, par fried, frozen, prepa...
#
#                                         foodPortions  \
# 0  [{'gramWeight': 33.9, 'value': 2.0, 'modifier'...
# 1  [{'gramWeight': 49.7, 'value': 5.0, 'modifier'...
# 2  [{'gramWeight': 129.0, 'value': 1.0, 'modifier...
# 3  [{'gramWeight': 48.6, 'value': 1.0, 'modifier'...
# 4  [{'gramWeight': 135.0, 'value': 1.0, 'modifier...
# 5  [{'gramWeight': 20.6, 'value': 1.0, 'modifier'...
# 6  [{'gramWeight': 28.4, 'value': 1.0, 'modifier'...
# 7  [{'gramWeight': 28.4, 'value': 1.0, 'modifier'...
# 8  [{'gramWeight': 7.0, 'value': 1.0, 'modifier':...
# 9  [{'gramWeight': 20.2, 'value': 1.0, 'modifier'...
#
#                                        foodNutrients
# 0  [{'number': '606', 'name': 'Fatty acids, total...
# 1  [{'number': '301', 'name': 'Calcium, Ca', 'uom...
# 2  [{'number': '301', 'name': 'Calcium, Ca', 'uom...
# 3  [{'number': '205', 'name': 'Carbohydrate, by d...
# 4  [{'number': '645', 'name': 'Fatty acids, total...
# 5  [{'number': '203', 'name': 'Protein', 'uom': '...
# 6  [{'number': '306', 'name': 'Potassium, K', 'uo...
# 7  [{'number': '306', 'name': 'Potassium, K', 'uo...
# 8  [{'number': '203', 'name': 'Protein', 'uom': '...
# 9  [{'number': '306', 'name': 'Potassium, K', 'uo...

# %% [markdown]
# ### Export to json

# %%
# df.to_csv('usda_foundation_foods.csv', index=False)
df.to_json('usda_foundation_foods.json', orient='records')
